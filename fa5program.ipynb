# %% [markdown]
# <a href="https://colab.research.google.com/github/luluv-ie/fa5programmingactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi, what are you buying?")
input("Enter item ")
int(input("Enter price ")
int(input("Enter quantity "))
#function

def total(a , b):
    return a * b

#main
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

print("The total is: ", total(num1, num2))
# Out:
# Hi, what are you buying?
# Enter itemBallpens
# Enter number 12
# Enter quantity 12
# Enter the first number: 10
# Enter the second number: 12
# The total is:  120
